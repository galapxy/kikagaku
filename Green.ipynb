# %%
import requests
response = requests.get("https://www.green-japan.com/search_key/01?key=7fd3y20b14r306abhlz3&keyword=")
print (response.text)
# Out:
# <!DOCTYPE html>
#
# <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type" />
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"1c874b5226","applicationID":"3857902","transactionName":"dA5WTEENX14DFhgWBlYTW1AcEVZTFAdfOghSGA==","queueTime":0,"applicationTime":323,"agent":""}</script>
# ...

# %%
from bs4 import BeautifulSoup
html_doc = requests.get("https://www.green-japan.com/search_key/01?key=7fd3y20b14r306abhlz3&keyword=").text
soup = BeautifulSoup(html_doc, 'html.parser') # BeautifulSoupの初期化
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <head>
#  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#  <script type="text/javascript">
#   window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"1c874b5226","applicationID":"3857902","transactionName":"dA5WTEENX14DFhgWBlYTW1AcEVZTFAdfOghSGA==","queueTime":0,"applicationTime":657,"agent":""}
#  </script>
#  <script type="text/javascript">
# ...

# %%
real_page_tags = soup.find_all("a")
for tag in real_page_tags:
 print(tag)
# Out:
# <a href="https://www.google.co.jp/chrome/browser/desktop/">Google Chrome</a>
# <a href="/" title="求人検索　転職サイトGreen（グリーン）">求人検索　転職サイトGreen（グリーン）</a>
# <a href="/search">求人を探す</a>
# <a href="/new">新着求人</a>
# <a href="/favorites/simple?sort=only_client_for_user">気になるリスト</a>
# <a href="/messages">メッセージ</a>
# <a class="lnk" href="/login" rel="nofollow">ログイン</a>
# <a class="lnk" href="/registrations/new?lid=head_lnk_reg" id="js-global_menu_reg">会員登録</a>
# <a class="lnk" href="/requests/common?lid=head_lnk_req" id="requestsLnk">採用ご担当者様へ</a>
# <a href="/">転職・求人サイトGreen</a>
# <a href="https://www.green-japan.com/features/sp354-0?lid=sp_bnr_srch"><img alt="Bnr sp354 8" height="93" src="https://den8lgfpmzfo0.cloudfront.net/assets/features/bnr_sp354_8-2730f8878a287cbd1634bfa37874cdee3ef96d14780c7a7a2973e7e84d0962ed.png" width="940"/></a>
# <a href="/login">こちら</a>
# <a class="js-search-result-box card-info " href="/job/46074" target="_blank">
# <div class="card-info__tag-area clearfix">
# ...

# %%
for tag in real_page_tags:
 print(tag.get("href"))
# Out:
# https://www.google.co.jp/chrome/browser/desktop/
# /
# /search
# /new
# /favorites/simple?sort=only_client_for_user
# /messages
# /login
# /registrations/new?lid=head_lnk_reg
# /requests/common?lid=head_lnk_req
# /
# https://www.green-japan.com/features/sp354-0?lid=sp_bnr_srch
# /login
# /job/46074
# /job/47097
# /job/44788
# /job/49400
# /job/46877
# /job/67296
# /job/57706
# /job/64284
# /job/60886
# /requests/common?lid=foot_lnk_req
# /contents/about
# /contents/privacy
# /contents/terms
# /contents/faq
# /contents/sitemap
# /requests/report_list
# /features-ranking
# /features-hurried
# /features-plurals
# /features-early
# /features-elect_few
# /features-venture
# /features-hot
# /features-otherwise
# /registrations/new
# https://www.green-japan.com/auth/facebook
# /passwords/new
# /registrations/new?lid=from_modal
# /profiles/edit?lid=pushm

# %%
soup.find_all("class": "companyname"})
